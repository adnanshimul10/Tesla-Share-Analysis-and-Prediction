# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv("Tesla.csv")
df.head()
# Out:
#         Date       Open   High        Low      Close    Volume  Adj Close
# 0  6/29/2010  19.000000  25.00  17.540001  23.889999  18766300  23.889999
# 1  6/30/2010  25.790001  30.42  23.299999  23.830000  17187100  23.830000
# 2   7/1/2010  25.000000  25.92  20.270000  21.959999   8218800  21.959999
# 3   7/2/2010  23.000000  23.10  18.709999  19.200001   5139800  19.200001
# 4   7/6/2010  20.000000  20.00  15.830000  16.110001   6866900  16.110001

# %%
df.shape
# Out:
# (1692, 7)

# %%
df.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  1692.000000  1692.000000  1692.000000  1692.000000  1.692000e+03
# mean    132.441572   134.769698   129.996223   132.428658  4.270741e+06
# std      94.309923    95.694914    92.855227    94.313187  4.295971e+06
# min      16.139999    16.629999    14.980000    15.800000  1.185000e+05
# 25%      30.000000    30.650000    29.215000    29.884999  1.194350e+06
# 50%     156.334999   162.370002   153.150002   158.160004  3.180700e+06
# 75%     220.557495   224.099999   217.119999   220.022503  5.662100e+06
# max     287.670013   291.420013   280.399994   286.040009  3.716390e+07
#
#          Adj Close
# count  1692.000000
# mean    132.428658
# std      94.313187
# min      15.800000
# 25%      29.884999
# 50%     158.160004
# 75%     220.022503
# max     286.040009

# %%
df.corr()
# Out:
#                Open      High       Low     Close    Volume  Adj Close
# Open       1.000000  0.999623  0.999605  0.999233  0.407515   0.999233
# High       0.999623  1.000000  0.999521  0.999691  0.416466   0.999691
# Low        0.999605  0.999521  1.000000  0.999656  0.397615   0.999656
# Close      0.999233  0.999691  0.999656  1.000000  0.406907   1.000000
# Volume     0.407515  0.416466  0.397615  0.406907  1.000000   0.406907
# Adj Close  0.999233  0.999691  0.999656  1.000000  0.406907   1.000000

# %%
corrMatrix = df.corr()
sns.heatmap(corrMatrix, annot=True)
plt.show()

# %%
df.head(3)
# Out:
#         Date       Open   High        Low      Close    Volume  Adj Close
# 0  6/29/2010  19.000000  25.00  17.540001  23.889999  18766300  23.889999
# 1  6/30/2010  25.790001  30.42  23.299999  23.830000  17187100  23.830000
# 2   7/1/2010  25.000000  25.92  20.270000  21.959999   8218800  21.959999

# %%
# change data column formate

df['Year'] = df["Date"].apply(lambda x:x.split('/')[2])
df["Month"] = df["Date"].apply(lambda x:x.split('/')[0])
df["Day"] = df["Date"].apply(lambda x:x.split('/')[1])

# %%
df['Date'] = pd.to_datetime(df["Date"])

# %%
df.head()
# Out:
#         Date       Open   High        Low      Close    Volume  Adj Close  \
# 0 2010-06-29  19.000000  25.00  17.540001  23.889999  18766300  23.889999
# 1 2010-06-30  25.790001  30.42  23.299999  23.830000  17187100  23.830000
# 2 2010-07-01  25.000000  25.92  20.270000  21.959999   8218800  21.959999
# 3 2010-07-02  23.000000  23.10  18.709999  19.200001   5139800  19.200001
# 4 2010-07-06  20.000000  20.00  15.830000  16.110001   6866900  16.110001
#
#    Year Month Day
# 0  2010     6  29
# 1  2010     6  30
# 2  2010     7   1
# 3  2010     7   2
# 4  2010     7   6

# %% [markdown]
# # droping 2010 and 2017 raws, because these year doesn't have  every month's value

# %%
df.drop(df[df["Year"]=="2010"].index, inplace=True)
df.drop(df[df["Year"]=="2017"].index, inplace=True)

# %%
df.shape
# Out:
# (1510, 10)

# %% [markdown]
# Drop Raw: 182

# %%
df.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  1510.000000  1510.000000  1510.000000  1510.000000  1.510000e+03
# mean    137.765510   140.194609   135.185550   137.726589  4.466171e+06
# std      91.784958    93.148252    90.305671    91.749316  4.381167e+06
# min      21.780001    22.270000    21.110001    21.830000  2.396000e+05
# 25%      31.804999    32.335001    31.002500    31.792500  1.309225e+06
# 50%     172.584999   177.534996   167.974998   173.229996  3.370550e+06
# 75%     220.114994   223.374996   216.780002   219.602501  5.865400e+06
# max     287.670013   291.420013   280.399994   286.040009  3.716390e+07
#
#          Adj Close
# count  1510.000000
# mean    137.726589
# std      91.749316
# min      21.830000
# 25%      31.792500
# 50%     173.229996
# 75%     219.602501
# max     286.040009

# %%
df.corr()
# Out:
#                Open      High       Low     Close    Volume  Adj Close
# Open       1.000000  0.999577  0.999551  0.999138  0.383597   0.999138
# High       0.999577  1.000000  0.999462  0.999654  0.393139   0.999654
# Low        0.999551  0.999462  1.000000  0.999614  0.372939   0.999614
# Close      0.999138  0.999654  0.999614  1.000000  0.382953   1.000000
# Volume     0.383597  0.393139  0.372939  0.382953  1.000000   0.382953
# Adj Close  0.999138  0.999654  0.999614  1.000000  0.382953   1.000000

# %%
corrMat = df.corr()
sns.heatmap(corrMat, annot=True)
plt.show()

# %%
g = sns.PairGrid(df)
g.map(sns.scatterplot)

# %%
gb_year = df.groupby("Year")

df_2011 = gb_year.get_group('2011')
df_2012 = gb_year.get_group('2012')
df_2013 = gb_year.get_group('2013')
df_2014 = gb_year.get_group('2014')
df_2015 = gb_year.get_group('2015')
df_2016 = gb_year.get_group('2016')

# %% [markdown]
# # Close price History plotting the data

# %%
plt.figure(figsize=(12, 7))
plt.title("Close Price History", fontsize=20)
plt.plot(df["Date"], df["Close"], color='r')
plt.xlabel("Year", fontsize=16)
plt.ylabel("Close Price USD", fontsize=16)
plt.grid(True)
plt.show()

# %% [markdown]
# # Open_Close Price History

# %%
plt.figure(figsize=(15, 10))
plt.title("Open Close Price History", fontsize=20)
plt.plot(df["Date"], df["Open"], color = 'r')
plt.plot(df["Date"], df["Close"], color='b')
plt.xlabel("Year", fontsize=16)
plt.ylabel("Price USD", fontsize=16)
plt.grid(True)
plt.show()

# %% [markdown]
# # Max Open and Close value of Tesla Share

# %%
df['Open'].max()
# Out:
# 287.670013

# %%
df[df['Open']==287.670013]
# Out:
#            Date        Open   High         Low       Close   Volume  \
# 1052 2014-09-03  287.670013  288.0  280.100006  281.190002  6772300
#
#        Adj Close  Year Month Day
# 1052  281.190002  2014     9   3

# %%
df['Close'].max()
# Out:
# 286.040009

# %%
df[df["Close"]==286.040009]
# Out:
#            Date       Open        High         Low       Close   Volume  \
# 1053 2014-09-04  284.01001  291.420013  280.399994  286.040009  8341700
#
#        Adj Close  Year Month Day
# 1053  286.040009  2014     9   4

# %% [markdown]
# # Max open and Max Close September, 2014

# %%
df_2014_9=df_2011[df["Month"]=='9']



x=df_2014_9['Day']
y=df_2014_9['Open']
z=df_2014_9['Close']
plt.figure(figsize=(12,7))
plt.style.use('seaborn-notebook')
plt.title('Max Open and Close "September,2014"',fontsize='20')
plt.plot(x,y,label="opening value",color='b',marker='o')
plt.plot(x,z,label="closing value",color='r',marker='o')
plt.xlabel("Day",fontsize='15')
plt.ylabel('USD Dollar$',fontsize='15')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\adnan\AppData\Local\Temp\ipykernel_9964\509683124.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_2014_9=df_2011[df["Month"]=='9']

# %% [markdown]
# # Min Open and Close value of Tesla Share

# %%
df['Open'].min()
# Out:
# 21.780001

# %%
df[df['Open']==21.780001]
# Out:
#           Date       Open   High   Low      Close   Volume  Adj Close  Year  \
# 166 2011-02-24  21.780001  22.58  21.5  22.530001  1055300  22.530001  2011
#
#     Month Day
# 166     2  24

# %%
df['Close'].min()
# Out:
# 21.83

# %%
df[df['Close']==21.83]
# Out:
#           Date   Open  High        Low  Close   Volume  Adj Close  Year Month  \
# 165 2011-02-23  22.18  22.5  21.110001  21.83  1605600      21.83  2011     2
#
#     Day
# 165  23

# %%
df_2011_2 = df_2011[df['Month']=='2']

x = df_2011_2['Day']
y = df_2011_2['Open']
z = df_2011_2['Close']
plt.figure(figsize=(12, 7))
plt.style.use('seaborn-notebook')
plt.title('Min Open and Close "February 2011"', fontsize='20')
plt.plot(x,y,label = 'opening value', color='b', marker = 'o')
plt.plot(x,z,label = 'closing value', color='r', marker='o')
plt.xlabel("Day", fontsize = '15')
plt.ylabel("USD Dollars$", fontsize='15')
plt.legend()
plt.grid()
plt.show()
# Out:
# C:\Users\adnan\AppData\Local\Temp\ipykernel_9964\3804141847.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_2011_2 = df_2011[df['Month']=='2']

# %% [markdown]
# # Stock volume of Tesla

# %%
plt.figure(figsize=(12,7))
plt.title('Stock volume of tesla', fontsize=20)
plt.plot(df['Date'], df['Volume'], color='blue')
plt.xlabel('Year', fontsize=16)
plt.ylabel('volume', fontsize = 16)
plt.show()

# %%
df['Volume'].max()
# Out:
# 37163900

# %%
df[df['Volume']==37163900]
# Out:
#           Date       Open       High        Low      Close    Volume  \
# 723 2013-05-14  94.220001  97.120003  81.150002  83.239998  37163900
#
#      Adj Close  Year Month Day
# 723  83.239998  2013     5  14

# %% [markdown]
# # Max volume month of tesla share value, May 2013

# %%
df_2013_5=df_2013[df["Month"]=='5']

x=df_2013_5['Day']
y=df_2013_5['Volume']
plt.figure(figsize=(12,7))
plt.style.use('seaborn-notebook')
plt.title('Max Volume  Month of Tesla Share Value.May,2013',fontsize='20')

plt.plot(x,y,label="Volume",color='b',marker='o')

plt.xlabel("Day",fontsize='15')
plt.ylabel('Volume',fontsize='15')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\adnan\AppData\Local\Temp\ipykernel_9964\3310201436.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_2013_5=df_2013[df["Month"]=='5']

# %%
df['Volume'].min()
# Out:
# 239600

# %%
df[df['Volume']==239600]
# Out:
#           Date       Open   High    Low  Close  Volume  Adj Close  Year Month  \
# 357 2011-11-25  31.549999  32.41  31.08  31.66  239600      31.66  2011    11
#
#     Day
# 357  25

# %% [markdown]
# # Min volume Month of Tesla share value, November 2011

# %%
df_2011_11 = df_2011[df["Month"]=="11"]

x = df_2011_11['Day']
y = df_2011_11['Volume']

plt.figure(figsize = (12, 7))
plt.style.use('seaborn-notebook')
plt.title("Min volume Monthe of Tesla share value, November, 2011", fontsize = "20")

plt.plot(x,y,label="volume", color='g', marker='o')
plt.xlabel("Day", fontsize='15')
plt.ylabel("Volume", fontsize='15')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\adnan\AppData\Local\Temp\ipykernel_9964\3149214988.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_2011_11 = df_2011[df["Month"]=="11"]

# %%
sns.set_style("whitegrid")
sns.relplot(data=df, x="Month", y="Open", hue="Year", kind="line", height=7, aspect=1).fig.suptitle("Opening value of Tesla 2011-16", fontsize=20,fontdict={"weight": "bold"})
# Out:
# Text(0.5, 0.98, 'Opening value of Tesla 2011-16')

# %%
sns.set_style("whitegrid")
sns.relplot(data=df, x="Month", y="Close", hue="Year", kind="line", height=7, aspect=1).fig.suptitle("Opening value of Tesla 2011-16", fontsize=20,fontdict={"weight": "bold"})
# Out:
# Text(0.5, 0.98, 'Opening value of Tesla 2011-16')

# %%
sns.relplot(data=df, x="Open", y="Close", hue="Month", kind="scatter", height=8, aspect=1)

# %%
sns.relplot(data=df, x="Open", y="Close", hue="Month", row="Year", kind="scatter", height=8, aspect=1)

# %%
sns.relplot(data=df, x="Open", y="Volume", hue = "Month", kind="scatter", height = 7, aspect = 1)
